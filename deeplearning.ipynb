# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/datasets/rjmanoj/credit-card-customer-churn-prediction/Churn_Modelling.csv

# %%
import pandas as pd

# %%
data= pd.read_csv('/kaggle/input/datasets/rjmanoj/credit-card-customer-churn-prediction/Churn_Modelling.csv')

# %%
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
data.shape
# Out:
# (10000, 14)

# %%
data.drop(columns= ['RowNumber','Surname'],axis=1,inplace=True)

# %% [markdown]
# Data cleaning

# %%
data.head()
# Out:
#    CustomerId  CreditScore Geography  Gender  Age  Tenure    Balance  \
# 0    15634602          619    France  Female   42       2       0.00
# 1    15647311          608     Spain  Female   41       1   83807.86
# 2    15619304          502    France  Female   42       8  159660.80
# 3    15701354          699    France  Female   39       1       0.00
# 4    15737888          850     Spain  Female   43       2  125510.82
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0              1          1               1        101348.88       1
# 1              1          0               1        112542.58       0
# 2              3          1               0        113931.57       1
# 3              2          0               0         93826.63       0
# 4              1          1               1         79084.10       0

# %%
data.isnull().sum()
# Out:
# CustomerId         0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       10000 non-null  int64
#  1   CreditScore      10000 non-null  int64
#  2   Geography        10000 non-null  object
#  3   Gender           10000 non-null  object
#  4   Age              10000 non-null  int64
#  5   Tenure           10000 non-null  int64
#  6   Balance          10000 non-null  float64
#  7   NumOfProducts    10000 non-null  int64
#  8   HasCrCard        10000 non-null  int64
#  9   IsActiveMember   10000 non-null  int64
#  10  EstimatedSalary  10000 non-null  float64
#  11  Exited           10000 non-null  int64
# dtypes: float64(2), int64(8), object(2)
# memory usage: 937.6+ KB

# %%
data.describe()

# %% [markdown]
# give description of numerical column
# hume include all nhi karna hai
# data.describe(include='all') <- agar hum ye likhte hai to vo not a number values ko bhi describe karega

# %%
data.info('Age')

# %%
data['Exited'].value_counts()

# %% [markdown]
# to know data particular column have binary classification or multiple classification

# %%
data['Gender'].value_counts()

# %%
data['Gender']=data['Gender'].map({'Male':1,'Female':0})

# %%
data.head(10)

# %%
data['Geography'].value_counts()

# %%
data = pd.get_dummies(data,columns=['Geography'],drop_first=True,dtype=int)

# %% [markdown]
# ONE HOT ENCODING

# %%
data.head(10)

# %%
x= data.drop(columns=['Exited'])

# %%
y=data['Exited']

# %%
x

# %%
y

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
x_train.shape

# %%
x_test.shape

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# Scaling

# %%
scaler = StandardScaler()

# %%
x_train=scaler.fit_transform(x_train)

# %%
x_train

# %%
x_test=scaler.transform(x_test)

# %%
x_test

# %%
import tensorflow
from tensorflow import keras 
from tensorflow.keras.layers import Dense  # dense use for adding the layer 
from tensorflow.keras.models import Sequential #Sequential is like a model

# %%
model = Sequential()

# %%
model.add(Dense(3,activation = 'sigmoid',input_dim=12))
model.add(Dense(2,activation = 'sigmoid'))
model.add(Dense(1,activation = 'sigmoid'))

# %%
model.summary()

# %%
model.compile(loss='binary_crossentropy',optimizer='Adam',metrics=['accuracy'])

# %%
history= model.fit(x_train,y_train,epochs=50)   # it divide data into 250badges 8000/250 = 1badge

# %%
y_predict=model.predict(x_test)

# %%
y_predict

# %%
y_prob=np.where(y_predict>0.5,1,0)

# %%
y_prob

# %%
from sklearn.metrics import accuracy_score

# %%
print('ANN result is =',accuracy_score(y_test,y_prob)*100)
